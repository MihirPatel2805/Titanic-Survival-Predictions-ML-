# %%
#importing	pakeges
import pandas as pd

# %%
df=pd.read_csv("test.csv")

# %%
df_gender=pd.read_csv('gender_submission.csv')
df['Survived']=df_gender['Survived']

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         1
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         1

# %%
df.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  Survived
# 413      0           A.5. 3236    8.0500   NaN        S         0
# 414      0            PC 17758  108.9000  C105        C         1
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S         0
# 416      0              359309    8.0500   NaN        S         0
# 417      1                2668   22.3583   NaN        C         0

# %%
df.shape
# Out:
# (418, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
#  11  Survived     418 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   418.000000  418.000000  332.000000  418.000000  418.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344
# std     120.810458    0.841838   14.181209    0.896760    0.981429
# min     892.000000    1.000000    0.170000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000
#
#              Fare    Survived
# count  417.000000  418.000000
# mean    35.627188    0.363636
# std     55.907576    0.481622
# min      0.000000    0.000000
# 25%      7.895800    0.000000
# 50%     14.454200    0.000000
# 75%     31.500000    1.000000
# max    512.329200    1.000000

# %%
df.nunique()
# Out:
# PassengerId    418
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# Survived         2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %%
# importing	pakeges
import matplotlib.pyplot as	plt
import seaborn as sns

# %%
plt.figure(figsize=(40,30))
sns.lineplot(y='Cabin',x='Age',c="r",marker="^",mfc="g",mec="b",data=df,alpha=0.7,lw=3)
plt.title("Titanic Survived Rate")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(30,20))
sns.barplot(x='Cabin',y='Age',hue='Sex',width=1,data=df)
plt.legend(title='Sex',title_fontsize="40",fontsize="30")
plt.title("Titanic	Survived	Rate",size=40)
plt.ylabel("Age",size=40)
plt.xlabel("Cabin",size=40)
plt.show()
# Out:
# C:\Users\mihir\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.pairplot(hue='Sex',data=df)
plt.show()
# Out:
# C:\Users\mihir\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(15,7))
plt.title("Titanic	Survived	Rate")
sns.lineplot(y='SibSp',x='Age',marker="o",c="g",mfc="b",mec="r",ls="--",data=df)
plt.grid()
plt.show()
# Out:
# C:\Users\mihir\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.barplot(df)
plt.title("Titanic Survived Rate")
plt.show()

# %%
sns.scatterplot(df)
plt.title("Titanic Survived Rate")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.title("Titanic Survived Rate")
sns.lineplot(x='SibSp',y='Cabin',c="r",marker="o",mfc="g",mec="b",data=df,alpha=1,lw=0.5)
plt.grid(axis="y")
plt.show()

# %%
sns.catplot(df)
plt.title("Titanic Survived Rate")
plt.show()
# Out:
# C:\Users\mihir\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lineplot(x='Survived',y='SibSp',data=df)
plt.title("Titanic Survived Rate")
plt.show()

# %%
sns.histplot(x='SibSp',y='Survived',data=df)
plt.title("Titanic Survived Rate")
plt.show()

# %%
sns.boxplot(df)
plt.title("Titanic Survived Rate")
plt.show()

# %%
sns.kdeplot(x='SibSp',y='Survived',data=df)
plt.title("Titanic Survived Rate")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])
corr = numeric_df.corr()

# %%
sns.heatmap(corr,cmap="Greens",annot=True)
plt.title("Titanic Survived Rate")
plt.show()

# %%
#importing	pakeges
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
#	Drop	columns	that	won't	be	useful	for	prediction	(PassengerId,	Name,	Ticket,	Cabin)
df=df.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 2
#       1 #	Drop	columns	that	won't	be	useful	for	prediction	(PassengerId,	Name,	Ticket,	Cabin)
# ----> 2 df	=df.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)
#       3 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
# ...

# %%
df
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked  Survived
# 12        1  female  23.0      1      0   82.2667        S         1
# 14        1  female  47.0      1      0   61.1750        S         1
# 24        1  female  48.0      1      3  262.3750        C         1
# 26        1  female  22.0      0      1   61.9792        C         1
# 28        1    male  41.0      0      0   30.5000        S         0
# ..      ...     ...   ...    ...    ...       ...      ...       ...
# 404       1    male  43.0      1      0   27.7208        C         0
# 405       2    male  20.0      0      0   13.8625        C         0
# 407       1    male  50.0      1      1  211.5000        C         0
# 411       1  female  37.0      1      0   90.0000        Q         1
# 414       1  female  39.0      0      0  108.9000        C         1
#
# [87 rows x 8 columns]

# %%
#	Encode	categorical	variables	('Sex')
label_encoder= LabelEncoder()
df['Sex']= label_encoder.fit_transform(df['Sex'])

# %%
 #	Separate	features	(X)	and	target	(y)
X = df.drop(['Survived','Embarked'], axis=1)
Y = df['Survived']

# %%
X
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare
# 12        1    0  23.0      1      0   82.2667
# 14        1    0  47.0      1      0   61.1750
# 24        1    0  48.0      1      3  262.3750
# 26        1    0  22.0      0      1   61.9792
# 28        1    1  41.0      0      0   30.5000
# ..      ...  ...   ...    ...    ...       ...
# 404       1    1  43.0      1      0   27.7208
# 405       2    1  20.0      0      0   13.8625
# 407       1    1  50.0      1      1  211.5000
# 411       1    0  37.0      1      0   90.0000
# 414       1    0  39.0      0      0  108.9000
#
# [87 rows x 6 columns]

# %%
Y
# Out:
# 12     1
# 14     1
# 24     1
# 26     1
# 28     0
#       ..
# 404    0
# 405    0
# 407    0
# 411    1
# 414    1
# Name: Survived, Length: 87, dtype: int64

# %%
#	Split	the	dataset	into	training	and	testing	sets	(80%	training,	20%	testing)
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (87, 6)
# (69, 6)
# (18, 6)

# %%
X_test
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare
# 378       1    1  55.0      0      0   50.0000
# 12        1    0  23.0      1      0   82.2667
# 114       1    0  63.0      1      0  221.7792
# 96        1    0  76.0      1      0   78.8500
# 59        1    0  36.0      0      0  262.3750
# 335       1    1  30.0      0      0   26.0000
# 53        1    0  28.0      3      2  263.0000
# 75        1    1  32.5      0      0  211.5000
# 28        1    1  41.0      0      0   30.5000
# 343       1    0  58.0      0      1  512.3292
# 407       1    1  50.0      1      1  211.5000
# 326       2    0  12.0      2      1   39.0000
# 252       1    1  27.0      1      0  136.7792
# 397       1    0  48.0      1      1   79.2000
# 405       2    1  20.0      0      0   13.8625
# 322       2    1  26.0      0      0   13.0000
# 156       1    0  29.0      0      0  221.7792
# 395       1    0  18.0      1      0   60.0000

# %%
y_test
# Out:
# 378    0
# 12     1
# 114    1
# 96     1
# 59     1
# 335    0
# 53     1
# 75     0
# 28     0
# 343    1
# 407    0
# 326    1
# 252    0
# 397    1
# 405    0
# 322    0
# 156    1
# 395    1
# Name: Survived, dtype: int64

# %%
y_train
# Out:
# 272    1
# 371    1
# 57     0
# 131    0
# 182    1
#       ..
# 81     0
# 308    0
# 356    1
# 68     0
# 242    0
# Name: Survived, Length: 69, dtype: int64

# %%
X_train
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare
# 272       1    0  26.0      1      0  136.7792
# 371       1    0  31.0      0      0  134.5000
# 57        3    1  25.0      0      0    7.6500
# 131       1    1  53.0      0      0   28.5000
# 182       1    0  18.0      1      0   53.1000
# ..      ...  ...   ...    ...    ...       ...
# 81        1    1  67.0      1      0  221.7792
# 308       1    1  55.0      1      1   93.5000
# 356       1    0  59.0      2      0   51.4792
# 68        1    1  31.0      0      0   28.5375
# 242       1    1  45.0      1      1  134.5000
#
# [69 rows x 6 columns]

# %%
 #Train	the	Logistic	Regression	model
model=LogisticRegression()
model.fit(X_train,	y_train)
# Out:
# LogisticRegression()

# %%
prediction_on_training_data	= model.predict(X_train)
accuracy_on_training_data =	accuracy_score(y_train,prediction_on_training_data)

# %%
print("Accuracy on training data: ",accuracy_on_training_data)
# Out:
# Accuracy on training data:  1.0

# %%
prediction_on_test_data=model.predict(X_test)
accuracy_on_test_data=accuracy_score(y_test,prediction_on_test_data)

# %%
print("Accuracy on testing	data: ",accuracy_on_test_data)
# Out:
# Accuracy on testing	data:  1.0

# %%
model.score(X,y)
# Out:
# 1.0

# %%
#Make	predictions	on	the	test	set
Prediction	=	model.predict([[1,0,26.0,1,0,136.7792]])			#Pclass,Sex,Age,SibSp,Parch,Fare
if Prediction == 1:											#	Survived=1,Not	Survived=0
    print("Survived")
else:
	print("Not Survived")
# Out:
# Survived
# C:\Users\mihir\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
